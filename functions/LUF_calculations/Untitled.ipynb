# %%
import xarray as xr
# Out:
# /storage/homefs/ch21o450/.local/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
LandUseList = "/storage/workspaces/wa_climate/climate_trt/chari/LUH2/remapped_luh2_ssp126.nc"

# %%
data = xr.open_dataset(LandUseList, decode_times=False)

# %%
test = data.primf.isel(time=65) == 0

# %%
data2 =xr.open_dataset(LandUseList, decode_times=False).secdf.isel(time=65)

# %%
data
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 86, lon: 720, lat: 360, bounds: 2)
# Coordinates:
#   * time       (time) float64 0.0 1.0 2.0 3.0 4.0 ... 81.0 82.0 83.0 84.0 85.0
#   * lon        (lon) float64 -179.8 -179.2 -178.8 -178.2 ... 178.8 179.2 179.8
#   * lat        (lat) float64 89.75 89.25 88.75 88.25 ... -88.75 -89.25 -89.75
# Dimensions without coordinates: bounds
# Data variables: (12/15)
#     c3ann      (time, lat, lon) float32 ...
#     c3nfx      (time, lat, lon) float32 ...
#     c3per      (time, lat, lon) float32 ...
#     c4ann      (time, lat, lon) float32 ...
#     c4per      (time, lat, lon) float32 ...
#     pastr      (time, lat, lon) float32 ...
#     ...         ...
#     secdf      (time, lat, lon) float32 ...
#     secdn      (time, lat, lon) float32 ...
#     secma      (time, lat, lon) float32 ...
#     secmb      (time, lat, lon) float32 ...
#     time_bnds  (time, bounds) int32 ...
#     urban      (time, lat, lon) float32 ...
# Attributes: (12/28)
# ...

# %%
data.plot()
